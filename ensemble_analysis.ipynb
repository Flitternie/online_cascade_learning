# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import re

# initialize a dict to store the data
llm_performance = {
    "GPT": {"IMDB": 0.9415, "ISEAR": 0.70345, "FEVER": 0.7998},
    "LLAMA": {"IMDB": 0.93332, "ISEAR": 0.6823, "FEVER": 0.7715}
}
llm_name = 'LLAMA'

# %%
dataset_name = 'ISEAR'
log_dir = f"./paper_logs/{llm_name}/{dataset_name.lower()}-llama-small/"
# get all .log files in the directory
files = [f for f in os.listdir(log_dir) if f.endswith('.log')]
files.sort()
# divide the files into different cascade sizes
cascades = {}
for f in files:
    cascade_size = f.split('_')
    if '_'.join(cascade_size[0:-1]) not in cascades:
        cascades['_'.join(cascade_size[0:-1])] = []
    cascades['_'.join(cascade_size[0:-1])].append(f)
cascades
# Out:
# {'LR_BERT-base': ['LR_BERT-base_0.001400.log',
#   'LR_BERT-base_0.001420.log',
#   'LR_BERT-base_0.001440.log',
#   'LR_BERT-base_0.001460.log',
#   'LR_BERT-base_0.001480.log',
#   'LR_BERT-base_0.001500.log',
#   'LR_BERT-base_0.001520.log',
#   'LR_BERT-base_0.001540.log',
#   'LR_BERT-base_0.001560.log',
#   'LR_BERT-base_0.001580.log',
#   'LR_BERT-base_0.001600.log',
#   'LR_BERT-base_0.001620.log',
#   'LR_BERT-base_0.001640.log',
#   'LR_BERT-base_0.001660.log',
#   'LR_BERT-base_0.001680.log',
#   'LR_BERT-base_0.001700.log',
#   'LR_BERT-base_0.001720.log',
#   'LR_BERT-base_0.001740.log',
#   'LR_BERT-base_0.001760.log',
#   'LR_BERT-base_0.001780.log',
#   'LR_BERT-base_0.001800.log',
#   'LR_BERT-base_0.001820.log',
#   'LR_BERT-base_0.001840.log',
#   'LR_BERT-base_0.001860.log',
#   'LR_BERT-base_0.001880.log',
#   'LR_BERT-base_0.001900.log',
#   'LR_BERT-base_0.001920.log',
#   'LR_BERT-base_0.001940.log',
#   'LR_BERT-base_0.001960.log',
#   'LR_BERT-base_0.001980.log',
#   'LR_BERT-base_0.002000.log',
#   'LR_BERT-base_0.002020.log',
#   'LR_BERT-base_0.002040.log',
#   'LR_BERT-base_0.002060.log',
#   'LR_BERT-base_0.002080.log',
#   'LR_BERT-base_0.002100.log',
#   'LR_BERT-base_0.002120.log',
#   'LR_BERT-base_0.002140.log',
#   'LR_BERT-base_0.002160.log',
#   'LR_BERT-base_0.002180.log',
#   'LR_BERT-base_0.002200.log',
#   'LR_BERT-base_0.002220.log',
#   'LR_BERT-base_0.002240.log',
#   'LR_BERT-base_0.002260.log',
#   'LR_BERT-base_0.002280.log',
#   'LR_BERT-base_0.002300.log',
#   'LR_BERT-base_0.002320.log',
#   'LR_BERT-base_0.002340.log',
#   'LR_BERT-base_0.002360.log',
#   'LR_BERT-base_0.002380.log',
#   'LR_BERT-base_0.002400.log',
#   'LR_BERT-base_0.002420.log',
#   'LR_BERT-base_0.002440.log',
#   'LR_BERT-base_0.002460.log',
#   'LR_BERT-base_0.002480.log',
#   'LR_BERT-base_0.002500.log',
#   'LR_BERT-base_0.002520.log',
#   'LR_BERT-base_0.002540.log',
#   'LR_BERT-base_0.002560.log',
#   'LR_BERT-base_0.002580.log',
#   'LR_BERT-base_0.002800.log',
#   'LR_BERT-base_0.002850.log',
#   'LR_BERT-base_0.002900.log',
#   'LR_BERT-base_0.002950.log',
#   'LR_BERT-base_0.003000.log',
#   'LR_BERT-base_0.003050.log',
#   'LR_BERT-base_0.003100.log',
#   'LR_BERT-base_0.003150.log',
#   'LR_BERT-base_0.003200.log',
#   'LR_BERT-base_0.003250.log',
#   'LR_BERT-base_0.003300.log',
#   'LR_BERT-base_0.003350.log',
#   'LR_BERT-base_0.003370.log',
#   'LR_BERT-base_0.003390.log',
#   'LR_BERT-base_0.003400.log',
#   'LR_BERT-base_0.003410.log',
#   'LR_BERT-base_0.003430.log',
#   'LR_BERT-base_0.003450.log',
#   'LR_BERT-base_0.003470.log',
#   'LR_BERT-base_0.003490.log',
#   'LR_BERT-base_0.003500.log',
#   'LR_BERT-base_0.003510.log',
#   'LR_BERT-base_0.003530.log',
#   'LR_BERT-base_0.003550.log',
#   'LR_BERT-base_0.003570.log',
#   'LR_BERT-base_0.003590.log',
#   'LR_BERT-base_0.003600.log',
#   'LR_BERT-base_0.003610.log',
#   'LR_BERT-base_0.003630.log',
#   'LR_BERT-base_0.003650.log',
#   'LR_BERT-base_0.003670.log',
#   'LR_BERT-base_0.003690.log',
#   'LR_BERT-base_0.003700.log',
#   'LR_BERT-base_0.003710.log',
#   'LR_BERT-base_0.003730.log',
#   'LR_BERT-base_0.003750.log',
#   'LR_BERT-base_0.003800.log',
#   'LR_BERT-base_0.003850.log',
#   'LR_BERT-base_0.003900.log',
#   'LR_BERT-base_0.003950.log']}

# %%
def stats(cascade_logs, cascade_costs):
    cascade_size = len(cascade_logs[0].split('_')) - 1
    print("cascade size: ", cascade_size)
    costs = []
    accus = []
    linear_accus = []
    # plot the data
    for f in cascade_logs:
        num_lines = sum(1 for line in open(log_dir + f))
        # read last line of the file
        with open(log_dir + f, 'r') as file:
            last_line = file.readlines()[-2]
        # data format: '''m1_prediction, m2_prediction, ..., llm_prediction, ground_truth, m1_proportion, m2_proportion, ..., m1_defer_prob, m2_defer_prob, ..., m1_score, m2_score, ..., m1_accuracy, m2_accuracy, llm_accuracy, overall_accuracy'''
        data = re.split(',', last_line.strip())
        model_prop = []
        linear_combination_acc = 0
        for k in range(cascade_size):
            model_prop.append(float(data[k + cascade_size + 2]))
            linear_combination_acc += float(data[k + cascade_size * 4 + 2]) * float(data[k + cascade_size + 2])
            
        llm_cost = 1 - sum(model_prop)
        model_accu = []
        for k in range(cascade_size):
            model_accu.append(float(data[k + cascade_size * 4 + 2]))
        llm_accuracy = float(data[k + cascade_size * 4 + 3])
        overall_accuracy = float(data[k + cascade_size * 4 + 4])
        linear_combination_acc += llm_accuracy * llm_cost
        print('file name: ', f, 'llm cost: ', int(llm_cost * num_lines), 'overall accuracy: ', overall_accuracy, 'online ensemble accuracy: ', linear_combination_acc)

# %%
cascade_name = 'LR_BERT-base'
cascade_logs = cascades[cascade_name]
cascade_costs = {
    "GPT": [1, 1182],
    "LLAMA": [1, 636]
}

stats(cascade_logs, cascade_costs)
# Out:
# cascade size:  2
# file name:  LR_BERT-base_0.001400.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001420.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001440.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001460.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001480.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001500.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001520.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001540.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001560.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001580.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001600.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001620.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001640.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001660.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001680.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001700.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001720.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001740.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001760.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001780.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001800.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001820.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001840.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001860.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001880.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001900.log llm cost:  3833 overall accuracy:  0.6892 linear combination accuracy:  0.6892
# file name:  LR_BERT-base_0.001920.log llm cost:  3810 overall accuracy:  0.6892 linear combination accuracy:  0.6870292199999999
# file name:  LR_BERT-base_0.001940.log llm cost:  3810 overall accuracy:  0.6892 linear combination accuracy:  0.6870292199999999
# file name:  LR_BERT-base_0.001960.log llm cost:  3810 overall accuracy:  0.6892 linear combination accuracy:  0.6870292199999999
# file name:  LR_BERT-base_0.001980.log llm cost:  3810 overall accuracy:  0.6892 linear combination accuracy:  0.6870223099999999
# file name:  LR_BERT-base_0.002000.log llm cost:  3760 overall accuracy:  0.6889 linear combination accuracy:  0.6820469499999999
# file name:  LR_BERT-base_0.002020.log llm cost:  3807 overall accuracy:  0.6895 linear combination accuracy:  0.686229
# file name:  LR_BERT-base_0.002040.log llm cost:  3796 overall accuracy:  0.6895 linear combination accuracy:  0.68526188
# file name:  LR_BERT-base_0.002060.log llm cost:  3764 overall accuracy:  0.6895 linear combination accuracy:  0.68218879
# file name:  LR_BERT-base_0.002080.log llm cost:  3810 overall accuracy:  0.6897 linear combination accuracy:  0.68708817
# file name:  LR_BERT-base_0.002100.log llm cost:  3791 overall accuracy:  0.6897 linear combination accuracy:  0.68521641
# file name:  LR_BERT-base_0.002120.log llm cost:  3740 overall accuracy:  0.6889 linear combination accuracy:  0.6793514599999999
# file name:  LR_BERT-base_0.002140.log llm cost:  3775 overall accuracy:  0.6892 linear combination accuracy:  0.6824047200000001
# file name:  LR_BERT-base_0.002160.log llm cost:  3734 overall accuracy:  0.6889 linear combination accuracy:  0.67842504
# file name:  LR_BERT-base_0.002180.log llm cost:  3718 overall accuracy:  0.6889 linear combination accuracy:  0.677237
# file name:  LR_BERT-base_0.002200.log llm cost:  3744 overall accuracy:  0.6889 linear combination accuracy:  0.6795978100000001
# file name:  LR_BERT-base_0.002220.log llm cost:  3719 overall accuracy:  0.6887 linear combination accuracy:  0.6768903600000001
# file name:  LR_BERT-base_0.002240.log llm cost:  3716 overall accuracy:  0.6887 linear combination accuracy:  0.67636129
# file name:  LR_BERT-base_0.002260.log llm cost:  3678 overall accuracy:  0.6887 linear combination accuracy:  0.6721461199999998
# file name:  LR_BERT-base_0.002280.log llm cost:  3695 overall accuracy:  0.6892 linear combination accuracy:  0.6747350899999999
# file name:  LR_BERT-base_0.002300.log llm cost:  3703 overall accuracy:  0.6892 linear combination accuracy:  0.67477037
# file name:  LR_BERT-base_0.002320.log llm cost:  3662 overall accuracy:  0.6887 linear combination accuracy:  0.67052928
# file name:  LR_BERT-base_0.002340.log llm cost:  3657 overall accuracy:  0.6884 linear combination accuracy:  0.67050824
# file name:  LR_BERT-base_0.002360.log llm cost:  3662 overall accuracy:  0.6884 linear combination accuracy:  0.6711035999999999
# file name:  LR_BERT-base_0.002380.log llm cost:  3621 overall accuracy:  0.6884 linear combination accuracy:  0.6670207999999999
# file name:  LR_BERT-base_0.002400.log llm cost:  3636 overall accuracy:  0.6882 linear combination accuracy:  0.66874718
# file name:  LR_BERT-base_0.002420.log llm cost:  3620 overall accuracy:  0.6879 linear combination accuracy:  0.66617602
# file name:  LR_BERT-base_0.002440.log llm cost:  3644 overall accuracy:  0.6889 linear combination accuracy:  0.66908792
# file name:  LR_BERT-base_0.002460.log llm cost:  3575 overall accuracy:  0.6882 linear combination accuracy:  0.66298086
# file name:  LR_BERT-base_0.002480.log llm cost:  3594 overall accuracy:  0.6892 linear combination accuracy:  0.6637906699999999
# file name:  LR_BERT-base_0.002500.log llm cost:  3575 overall accuracy:  0.6882 linear combination accuracy:  0.6619989
# file name:  LR_BERT-base_0.002520.log llm cost:  3554 overall accuracy:  0.6884 linear combination accuracy:  0.66175682
# file name:  LR_BERT-base_0.002540.log llm cost:  3531 overall accuracy:  0.6879 linear combination accuracy:  0.65838812
# file name:  LR_BERT-base_0.002560.log llm cost:  3562 overall accuracy:  0.6876 linear combination accuracy:  0.66109543
# file name:  LR_BERT-base_0.002580.log llm cost:  3535 overall accuracy:  0.6887 linear combination accuracy:  0.6584384499999999
# file name:  LR_BERT-base_0.002800.log llm cost:  3410 overall accuracy:  0.6868 linear combination accuracy:  0.6438278199999999
# file name:  LR_BERT-base_0.002850.log llm cost:  3390 overall accuracy:  0.6887 linear combination accuracy:  0.64434065
# file name:  LR_BERT-base_0.002900.log llm cost:  3273 overall accuracy:  0.684 linear combination accuracy:  0.63354921
# file name:  LR_BERT-base_0.002950.log llm cost:  3248 overall accuracy:  0.6842 linear combination accuracy:  0.6324743199999999
# file name:  LR_BERT-base_0.003000.log llm cost:  3222 overall accuracy:  0.6837 linear combination accuracy:  0.6323160699999999
# file name:  LR_BERT-base_0.003050.log llm cost:  3195 overall accuracy:  0.6808 linear combination accuracy:  0.62907872
# file name:  LR_BERT-base_0.003100.log llm cost:  3126 overall accuracy:  0.685 linear combination accuracy:  0.62644378
# file name:  LR_BERT-base_0.003150.log llm cost:  3122 overall accuracy:  0.684 linear combination accuracy:  0.62269496
# file name:  LR_BERT-base_0.003200.log llm cost:  2981 overall accuracy:  0.6793 linear combination accuracy:  0.61792011
# file name:  LR_BERT-base_0.003250.log llm cost:  2988 overall accuracy:  0.6816 linear combination accuracy:  0.61718961
# file name:  LR_BERT-base_0.003300.log llm cost:  2955 overall accuracy:  0.6769 linear combination accuracy:  0.60959951
# file name:  LR_BERT-base_0.003350.log llm cost:  2847 overall accuracy:  0.6746 linear combination accuracy:  0.61008394
# file name:  LR_BERT-base_0.003370.log llm cost:  2797 overall accuracy:  0.6756 linear combination accuracy:  0.60486593
# file name:  LR_BERT-base_0.003390.log llm cost:  1455 overall accuracy:  0.6198 linear combination accuracy:  0.57314527
# file name:  LR_BERT-base_0.003400.log llm cost:  1464 overall accuracy:  0.6271 linear combination accuracy:  0.57163885
# file name:  LR_BERT-base_0.003410.log llm cost:  2774 overall accuracy:  0.6772 linear combination accuracy:  0.60691598
# file name:  LR_BERT-base_0.003430.log llm cost:  2834 overall accuracy:  0.6798 linear combination accuracy:  0.6115967600000001
# file name:  LR_BERT-base_0.003450.log llm cost:  2688 overall accuracy:  0.6741 linear combination accuracy:  0.6040734799999999
# file name:  LR_BERT-base_0.003470.log llm cost:  2620 overall accuracy:  0.6694 linear combination accuracy:  0.5983504
# file name:  LR_BERT-base_0.003490.log llm cost:  1428 overall accuracy:  0.6193 linear combination accuracy:  0.57271245
# file name:  LR_BERT-base_0.003500.log llm cost:  2714 overall accuracy:  0.6715 linear combination accuracy:  0.5988856300000001
# file name:  LR_BERT-base_0.003510.log llm cost:  2683 overall accuracy:  0.6725 linear combination accuracy:  0.6018958999999999
# file name:  LR_BERT-base_0.003530.log llm cost:  2560 overall accuracy:  0.6735 linear combination accuracy:  0.59670296
# file name:  LR_BERT-base_0.003550.log llm cost:  1393 overall accuracy:  0.6219 linear combination accuracy:  0.56675402
# file name:  LR_BERT-base_0.003570.log llm cost:  1408 overall accuracy:  0.6334 linear combination accuracy:  0.57347596
# file name:  LR_BERT-base_0.003590.log llm cost:  2519 overall accuracy:  0.6652 linear combination accuracy:  0.5881534599999999
# file name:  LR_BERT-base_0.003600.log llm cost:  1373 overall accuracy:  0.5835 linear combination accuracy:  0.53458758
# file name:  LR_BERT-base_0.003610.log llm cost:  2591 overall accuracy:  0.6686 linear combination accuracy:  0.5900443799999999
# file name:  LR_BERT-base_0.003630.log llm cost:  2623 overall accuracy:  0.6696 linear combination accuracy:  0.59102678
# file name:  LR_BERT-base_0.003650.log llm cost:  1297 overall accuracy:  0.6083 linear combination accuracy:  0.5529347
# file name:  LR_BERT-base_0.003670.log llm cost:  2480 overall accuracy:  0.667 linear combination accuracy:  0.58807354
# file name:  LR_BERT-base_0.003690.log llm cost:  1211 overall accuracy:  0.5924 linear combination accuracy:  0.54742724
# file name:  LR_BERT-base_0.003700.log llm cost:  2314 overall accuracy:  0.6422 linear combination accuracy:  0.57093153
# file name:  LR_BERT-base_0.003710.log llm cost:  1258 overall accuracy:  0.5819 linear combination accuracy:  0.52580561
# file name:  LR_BERT-base_0.003730.log llm cost:  2177 overall accuracy:  0.6318 linear combination accuracy:  0.56681203
# file name:  LR_BERT-base_0.003750.log llm cost:  1124 overall accuracy:  0.4919 linear combination accuracy:  0.47301113
# file name:  LR_BERT-base_0.003800.log llm cost:  869 overall accuracy:  0.4551 linear combination accuracy:  0.44336684000000004
# file name:  LR_BERT-base_0.003850.log llm cost:  637 overall accuracy:  0.4541 linear combination accuracy:  0.44043712
# file name:  LR_BERT-base_0.003900.log llm cost:  628 overall accuracy:  0.4431 linear combination accuracy:  0.43279357
# file name:  LR_BERT-base_0.003950.log llm cost:  716 overall accuracy:  0.4473 linear combination accuracy:  0.43216752

# %%
# example: LR: 0.3024;0.3987;0.3439 -> 0.3987
def get_recall(model_string):
    return float(model_string.split(';')[1])

def stats_hatespeech(cascade_logs, cascade_costs):
    cascade_size = len(cascade_logs[0].split('_')) - 1
    print("cascade size: ", cascade_size)
    costs = []
    accus = []
    linear_accus = []
    # plot the data
    for f in cascade_logs:
        num_lines = sum(1 for line in open(log_dir + f))
        # read last line of the file
        with open(log_dir + f, 'r') as file:
            last_line = file.readlines()[-2]
        # data format: '''m1_prediction, m2_prediction, ..., llm_prediction, ground_truth, m1_proportion, m2_proportion, ..., m1_defer_prob, m2_defer_prob, ..., m1_score, m2_score, ..., m1_accuracy, m2_accuracy, llm_accuracy, overall_accuracy'''
        data = re.split(',', last_line.strip())
        model_prop = []
        linear_combination_acc = 0
        my_recall = 0
        for k in range(cascade_size):
            model_prop.append(float(data[k + cascade_size + 2]))
            linear_combination_acc += float(data[k + cascade_size * 4 + 2]) * float(data[k + cascade_size + 2])
            my_recall += get_recall(data[k + cascade_size * 6 + 3]) * float(data[k + cascade_size + 2])
            
        llm_cost = 1 - sum(model_prop)
        model_accu = []
        for k in range(cascade_size):
            model_accu.append(float(data[k + cascade_size * 4 + 2]))
        llm_accuracy = float(data[k + cascade_size * 4 + 3])
        overall_accuracy = float(data[k + cascade_size * 4 + 4])
        linear_combination_acc += llm_accuracy * llm_cost

        llm_cost = 1 - sum(model_prop)

        llm_recall = get_recall(data[-2])
        my_recall += llm_recall * llm_cost
        overall_recall = get_recall(data[-1])
        # print overall cost and recall
        print('file name: ', f, 'llm cost: ', int(llm_cost * num_lines), 'overall recall: ', overall_recall, 
              'online ensemble recall: ', float(my_recall), 'overall accuracy: ', overall_accuracy, 'online ensemble accuracy: ', float(linear_combination_acc))

# %%
dataset_name = 'hatespeech'
log_dir = f"./paper_logs/{llm_name}/{dataset_name.lower()}-llama-small/"
files = [f for f in os.listdir(log_dir) if f.endswith('.log')]
files.sort()
# divide the files into different cascade sizes
cascades = {}
for f in files:
    cascade_size = f.split('_')
    if '_'.join(cascade_size[0:-1]) not in cascades:
        cascades['_'.join(cascade_size[0:-1])] = []
    cascades['_'.join(cascade_size[0:-1])].append(f)

cascade_name = 'LR_BERT-base'
cascade_logs = cascades[cascade_name]
cascade_costs = {
    "GPT": [1, 1182],
    "LLAMA": [1, 636]
}

stats_hatespeech(cascade_logs, cascade_costs)
# Out:
# cascade size:  2
# file name:  LR_BERT-base_0.000001.log llm cost:  5103 overall recall:  0.827 linear combination recall:  0.8272132400000001 overall accuracy:  0.7815 linear combination accuracy:  0.77940018
# file name:  LR_BERT-base_0.000002.log llm cost:  5115 overall recall:  0.827 linear combination recall:  0.82845618 overall accuracy:  0.7808 linear combination accuracy:  0.7791023899999999
# file name:  LR_BERT-base_0.000003.log llm cost:  5115 overall recall:  0.827 linear combination recall:  0.82834512 overall accuracy:  0.7808 linear combination accuracy:  0.77910347
# file name:  LR_BERT-base_0.000004.log llm cost:  5117 overall recall:  0.827 linear combination recall:  0.82841692 overall accuracy:  0.7808 linear combination accuracy:  0.7790732899999999
# file name:  LR_BERT-base_0.000005.log llm cost:  5114 overall recall:  0.827 linear combination recall:  0.8282451000000001 overall accuracy:  0.7808 linear combination accuracy:  0.7790180800000001
# file name:  LR_BERT-base_0.000006.log llm cost:  5107 overall recall:  0.827 linear combination recall:  0.82783484 overall accuracy:  0.7812 linear combination accuracy:  0.7791081200000001
# file name:  LR_BERT-base_0.000007.log llm cost:  5104 overall recall:  0.827 linear combination recall:  0.8275733000000001 overall accuracy:  0.7812 linear combination accuracy:  0.77893363
# file name:  LR_BERT-base_0.000008.log llm cost:  5104 overall recall:  0.827 linear combination recall:  0.8276237900000001 overall accuracy:  0.7812 linear combination accuracy:  0.7789369500000001
# file name:  LR_BERT-base_0.000009.log llm cost:  5100 overall recall:  0.827 linear combination recall:  0.8271732399999999 overall accuracy:  0.7815 linear combination accuracy:  0.77922884
# file name:  LR_BERT-base_0.000010.log llm cost:  5081 overall recall:  0.8253 linear combination recall:  0.82533672 overall accuracy:  0.7804 linear combination accuracy:  0.7790580300000001
# file name:  LR_BERT-base_0.000020.log llm cost:  5071 overall recall:  0.8236 linear combination recall:  0.82436035 overall accuracy:  0.7808 linear combination accuracy:  0.77826159
# file name:  LR_BERT-base_0.000030.log llm cost:  5050 overall recall:  0.8236 linear combination recall:  0.8247417699999999 overall accuracy:  0.781 linear combination accuracy:  0.77823456
# file name:  LR_BERT-base_0.000040.log llm cost:  5049 overall recall:  0.8253 linear combination recall:  0.82296654 overall accuracy:  0.781 linear combination accuracy:  0.7788250000000001
# file name:  LR_BERT-base_0.000050.log llm cost:  5057 overall recall:  0.827 linear combination recall:  0.82438281 overall accuracy:  0.7812 linear combination accuracy:  0.7787326099999999
# file name:  LR_BERT-base_0.000060.log llm cost:  5051 overall recall:  0.827 linear combination recall:  0.82401268 overall accuracy:  0.7813 linear combination accuracy:  0.7784312299999999
# file name:  LR_BERT-base_0.000070.log llm cost:  5037 overall recall:  0.8253 linear combination recall:  0.82291135 overall accuracy:  0.7812 linear combination accuracy:  0.77767433
# file name:  LR_BERT-base_0.000080.log llm cost:  5036 overall recall:  0.8253 linear combination recall:  0.82270014 overall accuracy:  0.7813 linear combination accuracy:  0.7776073900000001
# file name:  LR_BERT-base_0.000090.log llm cost:  5023 overall recall:  0.8236 linear combination recall:  0.8221526 overall accuracy:  0.781 linear combination accuracy:  0.77768987
# file name:  LR_BERT-base_0.000100.log llm cost:  4986 overall recall:  0.822 linear combination recall:  0.8223723099999999 overall accuracy:  0.7813 linear combination accuracy:  0.7770400599999999
# file name:  LR_BERT-base_0.000200.log llm cost:  4678 overall recall:  0.8203 linear combination recall:  0.81839947 overall accuracy:  0.7832 linear combination accuracy:  0.7682136599999999
# file name:  LR_BERT-base_0.000300.log llm cost:  3936 overall recall:  0.7937 linear combination recall:  0.80896623 overall accuracy:  0.786 linear combination accuracy:  0.7432022800000001
# file name:  LR_BERT-base_0.000400.log llm cost:  3801 overall recall:  0.7953 linear combination recall:  0.7987187199999999 overall accuracy:  0.7883 linear combination accuracy:  0.7388005299999999
# file name:  LR_BERT-base_0.000500.log llm cost:  3087 overall recall:  0.7637 linear combination recall:  0.7954488399999999 overall accuracy:  0.7911 linear combination accuracy:  0.72351256
# file name:  LR_BERT-base_0.000600.log llm cost:  2863 overall recall:  0.7754 linear combination recall:  0.7994909399999999 overall accuracy:  0.7922 linear combination accuracy:  0.7081007500000001
# file name:  LR_BERT-base_0.000700.log llm cost:  2551 overall recall:  0.7654 linear combination recall:  0.79163481 overall accuracy:  0.7832 linear combination accuracy:  0.7079179
# file name:  LR_BERT-base_0.000800.log llm cost:  2265 overall recall:  0.7621 linear combination recall:  0.77307074 overall accuracy:  0.7911 linear combination accuracy:  0.72067965
# file name:  LR_BERT-base_0.000900.log llm cost:  2157 overall recall:  0.7554 linear combination recall:  0.7637487000000001 overall accuracy:  0.7871 linear combination accuracy:  0.6968058400000001
# file name:  LR_BERT-base_0.001000.log llm cost:  626 overall recall:  0.6922 linear combination recall:  0.68979637 overall accuracy:  0.7802 linear combination accuracy:  0.76468104
# file name:  LR_BERT-base_0.002000.log llm cost:  488 overall recall:  0.6306 linear combination recall:  0.60361588 overall accuracy:  0.783 linear combination accuracy:  0.7599030099999999
# file name:  LR_BERT-base_0.003000.log llm cost:  403 overall recall:  0.5674 linear combination recall:  0.54146417 overall accuracy:  0.7585 linear combination accuracy:  0.74945328
# file name:  LR_BERT-base_0.004000.log llm cost:  403 overall recall:  0.5674 linear combination recall:  0.54146417 overall accuracy:  0.7585 linear combination accuracy:  0.74945328
# file name:  LR_BERT-base_0.005000.log llm cost:  403 overall recall:  0.5674 linear combination recall:  0.54146417 overall accuracy:  0.7585 linear combination accuracy:  0.74945328
# file name:  LR_BERT-base_0.006000.log llm cost:  403 overall recall:  0.5674 linear combination recall:  0.54146417 overall accuracy:  0.7585 linear combination accuracy:  0.74945328
# file name:  LR_BERT-base_0.007000.log llm cost:  403 overall recall:  0.5674 linear combination recall:  0.54146417 overall accuracy:  0.7585 linear combination accuracy:  0.74945328
# file name:  LR_BERT-base_0.008000.log llm cost:  403 overall recall:  0.5674 linear combination recall:  0.54146417 overall accuracy:  0.7585 linear combination accuracy:  0.74945328
# file name:  LR_BERT-base_0.009000.log llm cost:  403 overall recall:  0.5674 linear combination recall:  0.54146417 overall accuracy:  0.7585 linear combination accuracy:  0.74945328
